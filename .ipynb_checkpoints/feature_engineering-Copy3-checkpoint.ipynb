# %% [markdown]
# # <img style="float: left; padding-right: 10px; width: 45px" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png"> CS-109A Introduction to Data Science
#
#
#
# ## Group #20: Final Project - World Cup Predictions
#
# **Harvard University**<br>
# **Fall 2018**<br>

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## 1 - Notebook Configuration

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegressionCV
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from sklearn.model_selection import cross_val_score

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# display preferences
# %matplotlib inline
#from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# ## 2 - Custom Functions

# %%
# function to calculate rolling exponentioally weighted moving average
def rwma(group, min_periods, span):
    # perform the ewma
    kwargs = dict(ignore_na=False, span=span, min_periods=min_periods, adjust=True)
    result = group.ewm(**kwargs).mean().shift().reset_index()
    result.rename(columns={result.columns[-1]: 'rwma'}, inplace=True)
    return result

# %%
# function to calculate rolling weighted moving average
def rmean(group,min_periods):
    # perform the mean
    kwargs = dict(window='3650d', min_periods=min_periods, win_type=None)
    #kwargs = dict(window='1825d', min_periods=min_periods, win_type=None)
    result = group.rolling(**kwargs).mean().shift().reset_index()
    result.rename(columns={result.columns[-1]: 'rmean'}, inplace=True)
    return result

# %% [markdown]
# ## 3 - Load Data, Examine and Prep

# %%
df = pd.read_csv("data/team/new_intl_results.csv")

# %%
# note: some teams played twice on certain dates (e.g. Chile on 5/30/2010)

# %%
df.head()
# Out:
#                   date home_team away_team  home_score  away_score tournament  \
# 0  1872-11-30 00:00:00  Scotland   England           0           0   Friendly
# 1  1873-03-08 00:00:00   England  Scotland           4           2   Friendly
# 2  1874-03-07 00:00:00  Scotland   England           2           1   Friendly
# 3  1875-03-06 00:00:00   England  Scotland           2           2   Friendly
# 4  1876-03-04 00:00:00  Scotland   England           3           0   Friendly
#
#       city   country  neutral
# 0  Glasgow  Scotland    False
# 1   London   England    False
# 2  Glasgow  Scotland    False
# 3   London   England    False
# 4  Glasgow  Scotland    False

# %%
df.date = df.date.values.astype("datetime64")
df['year'] = pd.DatetimeIndex(df['date']).year

# %%
# create yearly bins for plotting
year_bins = np.linspace(min(df.year),max(df.year), max(df.year) - min(df.year) + 1)

fig, ax = plt.subplots(1,1,figsize = (10,5))
ax.hist(df['year'], bins = year_bins, alpha = 0.2, label = 'All macthes')
ax.hist(df[df['tournament'] == 'Friendly']['year'], bins = year_bins, alpha = 0.2, label = 'Friendly')
ax.set_xlabel('Year')
ax.set_ylabel('Frequency')
ax.set_title('Number of Matches per Year')
ax.legend()
plt.show()

# %%
# create yearly bins for plotting
year_bins = np.linspace(min(df.year),max(df.year), max(df.year) - min(df.year) + 1)

fig, ax = plt.subplots(1,1,figsize = (10,5))
ax.hist(df['year'], bins = year_bins, alpha = 0.2, label = 'All macthes')
ax.hist(df[df['neutral'] == 1]['year'], bins = year_bins, alpha = 0.2, label = 'Neutral')
ax.set_xlabel('Year')
ax.set_ylabel('Frequency')
ax.set_title('Number of Matches per Year')
ax.legend()
plt.show()

# %%
# Find first available date after historical gap in dates
#start_date = min(df[df['year'] >= 1940]['date'])
#print('First date available after historical gap: {}'.format(start_date))

# %% [markdown]
# Two observations:
#  - REMOVE - It looks like history is not truly available all the back to 1872. For feature engineering purposes, we will opt to ignore soccer matches prior to 1/1/1968.
#  - A high percentage of matches fall in the 'Friendly' category.  We will have to make a decision in terms of how to include these matches in our feature engineering process.  The decision will be made based on which approach (i.e. to include or not to include Friendlies) performs best.

# %% [markdown]
# Let's remove the friendly matches from the dataset.  The friendly matches represent a high percentage of the data set, but friendly matches do not have the same stakes and therefore do not help us assess the true ability of teams.

# %%
# Exclude world cup matches
df = df[df['date'] < '2018-06-14']

# Exclude Friendlies
#df = df[df['tournament'] != 'Friendly'] # put back to exlude friendlies

# %% [markdown]
# ## 4 - Create Intermediary Features

# %% [markdown]
# ### 4.1 Result

# %%
# result variable
# constructed as follows:
# 1 for win
# 0 for draw
# -1 for loss
df['result'] = np.sign(df.home_score - df.away_score)

# %% [markdown]
# ### 4.2 Result-Plus

# %%
# result adjusted for venue
# -0.5 penalty if result obtained on home soil
# +0.5 reward if result obtained on opponent soil 
# Note: no penalty if achieved on neutral field)
df['result_plus'] = np.sign(df.home_score - df.away_score) - (.25 * (df.neutral==False)) ## put back to 25

# %% [markdown]
# ### 4.3 Sorted Match-Up

# %%
# Create a lookup value for all unique historical match-ups

df['unsorted_matchup'] = df['home_team'] + '|' + df['away_team']

df['sorted_matchup'] = np.where(df['home_team'] < df['away_team'], 
                                df['home_team'] + '|' + df['away_team'],
                                df['away_team'] + '|' + df['home_team'])

# %% [markdown]
# ### 4.4 Sorted Match-Up Result

# %%
# Store result of the sorted match up
df['sorted_result'] = np.where(df['home_team'] < df['away_team'], 
                               df['result'] ,
                               df['result'] * -1)

# %% [markdown]
# ### 4.5 Sorted Match-Up Result-Plus

# %%
# Store "result plus" for the sorted match up
df['sorted_result_plus'] = np.where(df['home_team'] < df['away_team'], 
                                    df['result_plus'] ,
                                    df['result_plus'] * -1)

# %% [markdown]
# ## 5 - Create Model Features

# %% [markdown]
# Now that the required intermediary fearures have been created, we will go on to split our data set into training and testing subsets.

# %%
df = df.sort_values('date')

# %%
# split the data features generated on the training dataset 
# will be copied over to test dataset later on

# train_df = df[df['date'] <= '2018-06-13']
# test_df = df[df['date'] > '2018-06-13']

# %%
#train_df[train_df.neutral == False].head()

# %%
# check output
#df[df['sorted_matchup'] == 'Brazil|France']

# %% [markdown]
# ### 5.1 - Historical Record vs Opponent

# %% [markdown]
# Defintions:
#  - **Historical Record vs Opponent:**
#      - **Variable Name**: hrvo_rwma
#      - **Description**: Lagging indicator of past performance vs opponent based on _results_ variable
#
#
#
#  - **Historical Record vs Opponent "Plus":**
#      - **Variable Name**: hrvop_rwma
#      - **Description**: Lagging indicator of past performance vs opponent based on _results-plus_ variable

# %% [markdown]
# ### 5.1.1 - Generate Features

# %%
# Create fake rows to store forward int'l ranking


fake_df1 = df.loc[df.groupby(['home_team','away_team']).date.idxmax()]

fake_df1
# Out:
#             date      home_team                away_team  home_score  \
# 37720 2016-05-29       Abkhazia           Chagos Islands           9
# 39515 2018-06-02       Abkhazia               Kárpátalja           0
# 39532 2018-06-03       Abkhazia          Northern Cyprus           2
# 35901 2014-06-07       Abkhazia                Occitania           0
# 37837 2016-06-05       Abkhazia                   Panjab           1
# 38610 2017-06-05       Abkhazia            South Ossetia           2
# 37759 2016-06-01       Abkhazia                    Sápmi           2
# 39553 2018-06-05       Abkhazia              Tamil Eelam           6
# 39482 2018-05-31       Abkhazia                    Tibet           3
# 39574 2018-06-07       Abkhazia  United Koreans in Japan           2
# 37740 2016-05-31       Abkhazia          Western Armenia           1
# 37442 2015-12-24    Afghanistan               Bangladesh           4
# 35236 2013-09-02    Afghanistan                   Bhutan           3
# 39381 2018-03-27    Afghanistan                 Cambodia           2
# 25122 2003-01-12    Afghanistan                    India           0
# 37086 2015-09-08    Afghanistan                    Japan           0
# 39077 2017-10-10    Afghanistan                   Jordan           3
# 35728 2014-05-12    Afghanistan               Kyrgyzstan           1
# 35762 2014-05-24    Afghanistan                     Laos           0
# 38613 2017-06-06    Afghanistan                 Maldives           2
# 33615 2011-12-09    Afghanistan                    Nepal           1
# 35225 2013-08-20    Afghanistan                 Pakistan           3
# 32958 2011-06-29    Afghanistan                Palestine           0
# 38457 2017-03-23    Afghanistan                Singapore           2
# 37451 2015-12-31    Afghanistan                Sri Lanka           5
# 36760 2015-06-11    Afghanistan                    Syria           0
# 28072 2006-04-03    Afghanistan                   Taiwan           2
# 30333 2008-08-03    Afghanistan               Tajikistan           0
# 35754 2014-05-22    Afghanistan             Turkmenistan           3
# 38523 2017-03-28    Afghanistan                  Vietnam           1
# ...          ...            ...                      ...         ...
# 36682 2015-05-17       Zimbabwe                Mauritius           2
# 35606 2014-01-12       Zimbabwe                  Morocco           0
# 35312 2013-09-08       Zimbabwe               Mozambique           1
# 30152 2008-06-08       Zimbabwe                  Namibia           2
# 35645 2014-02-01       Zimbabwe                  Nigeria           0
# 27659 2005-09-04       Zimbabwe                   Rwanda           3
# 12235 1982-07-25       Zimbabwe                  Réunion           2
# 27933 2006-01-23       Zimbabwe                  Senegal           0
# 38806 2017-06-30       Zimbabwe               Seychelles           6
# 33562 2011-11-15       Zimbabwe             South Africa           2
# 37879 2016-06-11       Zimbabwe                Swaziland           2
# 12778 1983-12-04       Zimbabwe              Switzerland           3
# 38310 2016-11-13       Zimbabwe                 Tanzania           3
# 20066 1997-01-12       Zimbabwe                     Togo           3
# 38420 2017-01-23       Zimbabwe                  Tunisia           2
# 37739 2016-05-31       Zimbabwe                   Uganda           2
# 38518 2017-03-26       Zimbabwe                   Zambia           0
# 29204 2007-07-01  Åland Islands                  Bermuda           0
# 27529 2005-07-14  Åland Islands         Falkland Islands           2
# 29230 2007-07-05  Åland Islands                    Frøya           3
# 21983 1999-06-28  Åland Islands                Gibraltar           2
# 36913 2015-06-29  Åland Islands                Greenland           0
# 18924 1995-07-16  Åland Islands                 Guersney           2
# 31250 2009-07-02  Åland Islands              Isle of Man           2
# 18929 1995-07-17  Åland Islands            Isle of Wight           0
# 31258 2009-07-03  Åland Islands                   Jersey           1
# 36920 2015-06-30  Åland Islands                  Menorca           1
# 38776 2017-06-26  Åland Islands             Saare County           0
# 38786 2017-06-27  Åland Islands                 Shetland           2
# 16452 1991-06-26  Åland Islands                 Ynys Môn           0
#
#        away_score                    tournament                 city  \
# 37720           0     ConIFA World Football Cup              Suhkumi
# 39515           2     ConIFA World Football Cup              Enfield
# 39532           2     ConIFA World Football Cup              Enfield
# 35901           1     ConIFA World Football Cup            Östersund
# 37837           1     ConIFA World Football Cup              Suhkumi
# 38610           1  ConIFA European Football Cup              Kyrenia
# 37759           0     ConIFA World Football Cup              Suhkumi
# 39553           0     ConIFA World Football Cup               Aveley
# 39482           0     ConIFA World Football Cup              Enfield
# 39574           0     ConIFA World Football Cup              Bromley
# 37740           0     ConIFA World Football Cup              Suhkumi
# 37442           0                      SAFF Cup   Thiruvananthapuram
# 35236           0                      SAFF Cup            Kathmandu
# 39381           1   AFC Asian Cup qualification             Dushanbe
# 25122           4                      SAFF Cup                Dhaka
# 37086           6  FIFA World Cup qualification              Teheran
# 39077           3   AFC Asian Cup qualification             Dushanbe
# 35728           0                      Friendly          Kuwait City
# 35762           0             AFC Challenge Cup            Addu City
# 38613           1                      Friendly                Dubai
# 33615           0                      SAFF Cup            New Delhi
# 35225           0                      Friendly                Kabul
# 32958           2  FIFA World Cup qualification           Tursunzoda
# 38457           1                      Friendly            al-Wakrah
# 37451           0                      SAFF Cup   Thiruvananthapuram
# 36760           6  FIFA World Cup qualification              Mashhad
# 28072           2             AFC Challenge Cup           Chittagong
# 30333           4             AFC Challenge Cup            Hyderabad
# 35754           1             AFC Challenge Cup            Addu City
# 38523           1   AFC Asian Cup qualification             Dushanbe
# ...           ...                           ...                  ...
# 36682           0                    COSAFA Cup  Moruleng-Saulspoort
# 35606           0  African Nations Championship            Cape Town
# 35312           1  FIFA World Cup qualification               Harare
# 30152           0  FIFA World Cup qualification               Harare
# 35645           1  African Nations Championship            Cape Town
# 27659           1  FIFA World Cup qualification               Harare
# 12235           3                      Friendly            Salisbury
# 27933           2        African Cup of Nations            Port Said
# 38806           0                    COSAFA Cup           Rustenburg
# 33562           1                      Friendly               Harare
# 37879           2                    COSAFA Cup             Windhoek
# 12778           2                      Friendly               Harare
# 38310           0                      Friendly               Harare
# 20066           0  FIFA World Cup qualification               Harare
# 38420           4        African Cup of Nations           Libreville
# 37739           0                      Friendly               Harare
# 38518           0                      Friendly               Harare
# 29204           2                  Island Games               Rhodos
# 27529           1                  Island Games             Shetland
# 29230           1                  Island Games               Rhodos
# 21983           1                  Island Games             Väskinde
# 36913           2                  Island Games          St. Clement
# 18924           2                  Island Games            Gibraltar
# 31250           1                  Island Games               Jomala
# 18929           5                  Island Games            Gibraltar
# 31258           2                  Island Games            Mariehamn
# 36920           3                  Island Games          St. Clement
# 38776           0                  Island Games              Fardhem
# 38786           1                  Island Games                Visby
# 16452           1                  Island Games                Åland
#
#                     country  neutral  year  result  result_plus  \
# 37720               Georgia    False  2016       1         0.75
# 39515               England     True  2018      -1        -1.00
# 39532               England     True  2018       0         0.00
# 35901                Sweden     True  2014      -1        -1.00
# 37837               Georgia    False  2016       0        -0.25
# 38610       Northern Cyprus     True  2017       1         1.00
# 37759               Georgia    False  2016       1         0.75
# 39553               England     True  2018       1         1.00
# 39482               England     True  2018       1         1.00
# 39574               England     True  2018       1         1.00
# 37740               Georgia    False  2016       1         0.75
# 37442                 India     True  2015       1         1.00
# 35236                 Nepal     True  2013       1         1.00
# 39381            Tajikistan     True  2018       1         1.00
# 25122            Bangladesh     True  2003      -1        -1.00
# 37086                  Iran     True  2015      -1        -1.00
# 39077            Tajikistan     True  2017       0         0.00
# 35728                Kuwait     True  2014       1         1.00
# 35762              Maldives     True  2014       0         0.00
# 38613  United Arab Emirates     True  2017       1         1.00
# 33615                 India     True  2011       1         1.00
# 35225           Afghanistan    False  2013       1         0.75
# 32958            Tajikistan     True  2011      -1        -1.00
# 38457                 Qatar     True  2017       1         1.00
# 37451                 India     True  2015       1         1.00
# 36760                  Iran     True  2015      -1        -1.00
# 28072            Bangladesh     True  2006       0         0.00
# 30333                 India     True  2008      -1        -1.00
# 35754              Maldives     True  2014       1         1.00
# 38523            Tajikistan     True  2017       0         0.00
# ...                     ...      ...   ...     ...          ...
# 36682          South Africa     True  2015       1         1.00
# 35606          South Africa     True  2014       0         0.00
# 35312              Zimbabwe    False  2013       0        -0.25
# 30152              Zimbabwe    False  2008       1         0.75
# 35645          South Africa     True  2014      -1        -1.00
# 27659              Zimbabwe    False  2005       1         0.75
# 12235              Zimbabwe    False  1982      -1        -1.25
# 27933                 Egypt     True  2006      -1        -1.00
# 38806          South Africa     True  2017       1         1.00
# 33562              Zimbabwe    False  2011       1         0.75
# 37879               Namibia     True  2016       0         0.00
# 12778              Zimbabwe    False  1983       1         0.75
# 38310              Zimbabwe    False  2016       1         0.75
# 20066              Zimbabwe    False  1997       1         0.75
# 38420                 Gabon     True  2017      -1        -1.00
# 37739              Zimbabwe    False  2016       1         0.75
# 38518              Zimbabwe    False  2017       0        -0.25
# 29204                Greece     True  2007      -1        -1.00
# 27529              Scotland     True  2005       1         1.00
# 29230                Greece     True  2007       1         1.00
# 21983                Sweden     True  1999       1         1.00
# 36913                Jersey     True  2015      -1        -1.00
# 18924             Gibraltar     True  1995       0         0.00
# 31250                Sweden    False  2009       1         0.75
# 18929             Gibraltar     True  1995      -1        -1.00
# 31258                Sweden    False  2009      -1        -1.25
# 36920                Jersey     True  2015      -1        -1.00
# 38776                Sweden     True  2017       0         0.00
# 38786                Sweden     True  2017       1         1.00
# 16452               Finland    False  1991      -1        -1.25
#
#                        unsorted_matchup                    sorted_matchup  \
# 37720           Abkhazia|Chagos Islands           Abkhazia|Chagos Islands
# 39515               Abkhazia|Kárpátalja               Abkhazia|Kárpátalja
# 39532          Abkhazia|Northern Cyprus          Abkhazia|Northern Cyprus
# 35901                Abkhazia|Occitania                Abkhazia|Occitania
# 37837                   Abkhazia|Panjab                   Abkhazia|Panjab
# 38610            Abkhazia|South Ossetia            Abkhazia|South Ossetia
# 37759                    Abkhazia|Sápmi                    Abkhazia|Sápmi
# 39553              Abkhazia|Tamil Eelam              Abkhazia|Tamil Eelam
# 39482                    Abkhazia|Tibet                    Abkhazia|Tibet
# 39574  Abkhazia|United Koreans in Japan  Abkhazia|United Koreans in Japan
# 37740          Abkhazia|Western Armenia          Abkhazia|Western Armenia
# 37442            Afghanistan|Bangladesh            Afghanistan|Bangladesh
# 35236                Afghanistan|Bhutan                Afghanistan|Bhutan
# 39381              Afghanistan|Cambodia              Afghanistan|Cambodia
# 25122                 Afghanistan|India                 Afghanistan|India
# 37086                 Afghanistan|Japan                 Afghanistan|Japan
# 39077                Afghanistan|Jordan                Afghanistan|Jordan
# 35728            Afghanistan|Kyrgyzstan            Afghanistan|Kyrgyzstan
# 35762                  Afghanistan|Laos                  Afghanistan|Laos
# 38613              Afghanistan|Maldives              Afghanistan|Maldives
# 33615                 Afghanistan|Nepal                 Afghanistan|Nepal
# 35225              Afghanistan|Pakistan              Afghanistan|Pakistan
# 32958             Afghanistan|Palestine             Afghanistan|Palestine
# 38457             Afghanistan|Singapore             Afghanistan|Singapore
# 37451             Afghanistan|Sri Lanka             Afghanistan|Sri Lanka
# 36760                 Afghanistan|Syria                 Afghanistan|Syria
# 28072                Afghanistan|Taiwan                Afghanistan|Taiwan
# 30333            Afghanistan|Tajikistan            Afghanistan|Tajikistan
# 35754          Afghanistan|Turkmenistan          Afghanistan|Turkmenistan
# 38523               Afghanistan|Vietnam               Afghanistan|Vietnam
# ...                                 ...                               ...
# 36682                Zimbabwe|Mauritius                Mauritius|Zimbabwe
# 35606                  Zimbabwe|Morocco                  Morocco|Zimbabwe
# 35312               Zimbabwe|Mozambique               Mozambique|Zimbabwe
# 30152                  Zimbabwe|Namibia                  Namibia|Zimbabwe
# 35645                  Zimbabwe|Nigeria                  Nigeria|Zimbabwe
# 27659                   Zimbabwe|Rwanda                   Rwanda|Zimbabwe
# 12235                  Zimbabwe|Réunion                  Réunion|Zimbabwe
# 27933                  Zimbabwe|Senegal                  Senegal|Zimbabwe
# 38806               Zimbabwe|Seychelles               Seychelles|Zimbabwe
# 33562             Zimbabwe|South Africa             South Africa|Zimbabwe
# 37879                Zimbabwe|Swaziland                Swaziland|Zimbabwe
# 12778              Zimbabwe|Switzerland              Switzerland|Zimbabwe
# 38310                 Zimbabwe|Tanzania                 Tanzania|Zimbabwe
# 20066                     Zimbabwe|Togo                     Togo|Zimbabwe
# 38420                  Zimbabwe|Tunisia                  Tunisia|Zimbabwe
# 37739                   Zimbabwe|Uganda                   Uganda|Zimbabwe
# 38518                   Zimbabwe|Zambia                   Zambia|Zimbabwe
# 29204             Åland Islands|Bermuda             Bermuda|Åland Islands
# 27529    Åland Islands|Falkland Islands    Falkland Islands|Åland Islands
# 29230               Åland Islands|Frøya               Frøya|Åland Islands
# 21983           Åland Islands|Gibraltar           Gibraltar|Åland Islands
# 36913           Åland Islands|Greenland           Greenland|Åland Islands
# 18924            Åland Islands|Guersney            Guersney|Åland Islands
# 31250         Åland Islands|Isle of Man         Isle of Man|Åland Islands
# 18929       Åland Islands|Isle of Wight       Isle of Wight|Åland Islands
# 31258              Åland Islands|Jersey              Jersey|Åland Islands
# 36920             Åland Islands|Menorca             Menorca|Åland Islands
# 38776        Åland Islands|Saare County        Saare County|Åland Islands
# 38786            Åland Islands|Shetland            Shetland|Åland Islands
# 16452            Åland Islands|Ynys Môn            Ynys Môn|Åland Islands
#
#        sorted_result  sorted_result_plus
# 37720              1                0.75
# 39515             -1               -1.00
# 39532              0                0.00
# 35901             -1               -1.00
# 37837              0               -0.25
# 38610              1                1.00
# 37759              1                0.75
# 39553              1                1.00
# 39482              1                1.00
# 39574              1                1.00
# 37740              1                0.75
# 37442              1                1.00
# 35236              1                1.00
# 39381              1                1.00
# 25122             -1               -1.00
# 37086             -1               -1.00
# 39077              0                0.00
# 35728              1                1.00
# 35762              0                0.00
# 38613              1                1.00
# 33615              1                1.00
# 35225              1                0.75
# 32958             -1               -1.00
# 38457              1                1.00
# 37451              1                1.00
# 36760             -1               -1.00
# 28072              0                0.00
# 30333             -1               -1.00
# 35754              1                1.00
# 38523              0                0.00
# ...              ...                 ...
# 36682             -1               -1.00
# 35606              0               -0.00
# 35312              0                0.25
# 30152             -1               -0.75
# 35645              1                1.00
# 27659             -1               -0.75
# 12235              1                1.25
# 27933              1                1.00
# 38806             -1               -1.00
# 33562             -1               -0.75
# 37879              0               -0.00
# 12778             -1               -0.75
# 38310             -1               -0.75
# 20066             -1               -0.75
# 38420              1                1.00
# 37739             -1               -0.75
# 38518              0                0.25
# 29204              1                1.00
# 27529             -1               -1.00
# 29230             -1               -1.00
# 21983             -1               -1.00
# 36913              1                1.00
# 18924              0               -0.00
# 31250             -1               -0.75
# 18929              1                1.00
# 31258              1                1.25
# 36920              1                1.00
# 38776              0               -0.00
# 38786             -1               -1.00
# 16452              1                1.25
#
# [10482 rows x 16 columns]

# %%
                            
fake_df1['date'] = '2099-12-31'
fake_df1['tournament'] = 'Placeholder'

fake_df1
# fake_df = pd.DataFrame(df_tall.team.unique(),columns=['team'])
# fake_df['date'] = '2099-12-31'
# fake_df.date = fake_df.date.values.astype("datetime64")
# fake_df['home'] = '0'
# fake_df['result'] = '0'
# fake_df['result_plus'] = '0'
# fake_df['tournament'] = 'Placeholder'
# fake_df.set_index('date', inplace=True)
# fake_df.head()


df = pd.concat([df,fake_df1], sort=True)

# %%
df.set_index('date',inplace=True,drop=True)

# %%
# create new dataframe (df_vs_oppo) to store rolling record vs opponent using custom rolling weighted average function (rwma)
df_vs_oppo  = df.groupby('sorted_matchup')[['sorted_result','sorted_result_plus']].apply(rwma,0,25)

# %%
df.reset_index(inplace=True)

# %%
# rename columns, as group by generates undesirable column names
df_vs_oppo = df_vs_oppo.rename(columns={'sorted_result':'hrvo_rwma', 
                                        'rwma':'hrvop_rwma' })

df_vs_oppo.reset_index(inplace=True)

df_vs_oppo = df_vs_oppo.drop(columns = 'level_1')

# fill first match-up where values for sorted_result_rwma and sorted_result_plus_rwma will always be N/A with zeroes.
df_vs_oppo['hrvo_rwma'] = df_vs_oppo['hrvo_rwma'].fillna(0)
df_vs_oppo['hrvop_rwma'] = df_vs_oppo['hrvop_rwma'].fillna(0)

# %%
cnt = pd.DataFrame(df_vs_oppo.groupby(['date','sorted_matchup']).size())
cnt = cnt.reset_index()
cnt.head()

cnt = cnt.rename(columns = {0:'count'})

cnt[cnt['count'] != 1]
# Out:
#             date                             sorted_matchup  count
# 430   1916-08-15                          Argentina|Uruguay      2
# 433   1916-10-01                          Argentina|Uruguay      2
# 777   1924-05-25                          Argentina|Uruguay      2
# 1181  1929-06-16                          Argentina|Uruguay      2
# 2437  1944-10-10               Barbados|Trinidad and Tobago      2
# 8810  1974-02-17                       New Caledonia|Tahiti      2
# 10224 1977-10-22                            Barbados|Guyana      2
# 10931 1979-10-22  Guadeloupe|St. Vincent and the Grenadines      2
# 28660 2006-11-19                           Tajikistan|Tibet      2
# 28665 2006-11-20                 Northern Cyprus|Tajikistan      2
# 28669 2006-11-21                       Greenland|Kyrgyzstan      2
# 28672 2006-11-21                      Northern Cyprus|Tibet      2
# 39596 2099-12-31                        Abkhazia|Kárpátalja      2
# 39597 2099-12-31                   Abkhazia|Northern Cyprus      2
# 39603 2099-12-31                             Abkhazia|Sápmi      2
# 39608 2099-12-31                     Afghanistan|Bangladesh      2
# 39609 2099-12-31                         Afghanistan|Bhutan      2
# 39610 2099-12-31                       Afghanistan|Cambodia      2
# 39613 2099-12-31                          Afghanistan|India      2
# 39616 2099-12-31                          Afghanistan|Japan      2
# 39617 2099-12-31                         Afghanistan|Jordan      2
# 39620 2099-12-31                     Afghanistan|Kyrgyzstan      2
# 39621 2099-12-31                           Afghanistan|Laos      2
# 39624 2099-12-31                       Afghanistan|Maldives      2
# 39626 2099-12-31                          Afghanistan|Nepal      2
# 39628 2099-12-31                       Afghanistan|Pakistan      2
# 39629 2099-12-31                      Afghanistan|Palestine      2
# 39633 2099-12-31                      Afghanistan|Singapore      2
# 39634 2099-12-31                      Afghanistan|Sri Lanka      2
# 39635 2099-12-31                          Afghanistan|Syria      2
# ...          ...                                        ...    ...
# 46026 2099-12-31                             Tunisia|Uganda      2
# 46028 2099-12-31               Tunisia|United Arab Emirates      2
# 46032 2099-12-31                         Tunisia|Yugoslavia      2
# 46033 2099-12-31                             Tunisia|Zambia      2
# 46034 2099-12-31                           Tunisia|Zimbabwe      2
# 46035 2099-12-31                                 Turkey|USA      2
# 46036 2099-12-31                             Turkey|Ukraine      2
# 46038 2099-12-31                               Turkey|Wales      2
# 46039 2099-12-31                          Turkey|Yugoslavia      2
# 46040 2099-12-31          Turkmenistan|United Arab Emirates      2
# 46041 2099-12-31                    Turkmenistan|Uzbekistan      2
# 46042 2099-12-31                       Turkmenistan|Vietnam      2
# 46046 2099-12-31                             Tuvalu|Vanuatu      2
# 46047 2099-12-31                                USA|Ukraine      2
# 46048 2099-12-31                                USA|Uruguay      2
# 46052 2099-12-31                              Uganda|Zambia      2
# 46053 2099-12-31                            Uganda|Zanzibar      2
# 46054 2099-12-31                            Uganda|Zimbabwe      2
# 46058 2099-12-31                              Ukraine|Wales      2
# 46060 2099-12-31            United Arab Emirates|Uzbekistan      2
# 46061 2099-12-31               United Arab Emirates|Vietnam      2
# 46062 2099-12-31                 United Arab Emirates|Yemen      2
# 46066 2099-12-31                          Uruguay|Venezuela      2
# 46068 2099-12-31                         Uruguay|Yugoslavia      2
# 46069 2099-12-31                         Uzbekistan|Vietnam      2
# 46070 2099-12-31                           Uzbekistan|Yemen      2
# 46075 2099-12-31                           Wales|Yugoslavia      2
# 46079 2099-12-31                     Ynys Môn|Åland Islands      2
# 46080 2099-12-31                            Zambia|Zanzibar      2
# 46081 2099-12-31                            Zambia|Zimbabwe      2
#
# [4005 rows x 3 columns]

# %%
len(df_vs_oppo)
# Out:
# 50088

# %%
# below is needed to handle duplicates due to certain teams playing two matches on the same date
df_vs_oppo = df_vs_oppo.groupby(['sorted_matchup','date']).mean()
df_vs_oppo = df_vs_oppo.reset_index()

# %%
cnt = pd.DataFrame(df_vs_oppo.groupby(['date','sorted_matchup']).size())
cnt = cnt.reset_index()
cnt.head()

cnt = cnt.rename(columns = {0:'count'})

cnt[cnt['count'] != 1]
# Out:
# Empty DataFrame
# Columns: [date, sorted_matchup, count]
# Index: []

# %%
len(df_vs_oppo)
# Out:
# 46083

# %% [markdown]
# ### 5.1.2 - Examine Features

# %% [markdown]
# Let's take a look at match results vs our newly engineered variables:

# %%
temp_df = df[df['sorted_matchup'] == 'France|Spain']

temp_df_vs_oppo = df_vs_oppo[df_vs_oppo['sorted_matchup'] == 'France|Spain']

fig, ax = plt.subplots(1,1,figsize = (20,5))

ax.plot(temp_df['date'] , temp_df['sorted_result'], 'o', label = 'sorted_result', alpha = 0.2, color = 'blue')
ax.plot(temp_df['date'] , temp_df['sorted_result_plus'] , 'o', label = 'sorted_result_plus', alpha = 0.2, color = 'red')
ax.plot(temp_df_vs_oppo['date'] , temp_df_vs_oppo['hrvo_rwma'] , '-', label = 'hrvo_rwma', alpha = 0.5, color = 'blue')
ax.plot(temp_df_vs_oppo['date'] , temp_df_vs_oppo['hrvop_rwma'] , '-', label = 'hrvop_rwma', alpha = 0.5, color = 'red')
ax.axhline(0, linestyle = '--', alpha = 0.2)

ax.set_xlabel('Year')
ax.set_ylabel('Match Results and Moving Averages')
ax.set_title('Illustration of "Historical Record vs Opponent" Feature: Argentina vs. Brazil')

ax.legend()
plt.show()

# %%
print(len(df))
print(len(df_vs_oppo))
df = df.merge(df_vs_oppo[['sorted_matchup','date','hrvo_rwma','hrvop_rwma']], 
                  how = 'inner',
                  left_on=['sorted_matchup','date'], 
                  right_on=['sorted_matchup','date'])



print(len(df))
# Out:
# 50088
# 46083
# 50088

# %%
sns.pairplot(df, vars = ['hrvo_rwma' , 'hrvop_rwma'] , hue="sorted_result")

# %%
# Look at France vs Spain
temp_pair_plot_df = df[(df['sorted_matchup'] == 'Argentina|Brazil')]
sns.pairplot(temp_pair_plot_df, vars = ['hrvo_rwma' , 'hrvop_rwma'] , hue="sorted_result")

# %%
# Look at France vs Spain
temp_pair_plot_df = df[df['sorted_matchup'] == 'Mexico|USA']
sns.pairplot(temp_pair_plot_df, vars = ['hrvo_rwma' , 'hrvop_rwma'] , hue="sorted_result")

# %% [markdown]
# Based on the above, it appears that these incorporatng a feature capturing the record of the team versus the same opponent could help determining match outcomes.  Teams with a positive record versus an specific opponent appear to win matches more often than not.

# %%
# Check how many matches have taken place for all the matchups in our data set.
matchup_bins = np.linspace(4,99,20)
matchup_bins = np.linspace(1,70,70)
fig, ax = plt.subplots(1,1,figsize = (10,5))
ax.hist(df_vs_oppo.groupby('sorted_matchup').size(), bins = matchup_bins, alpha = .5)
ax.set_ylabel('Frequency')
ax.set_xlabel('Number of Historical Matchups')
plt.show()

# %% [markdown]
# Based on the histogram above, it appears that most teams have played each other more than five times, which reinforces the notion that we may have enough one-on-one match-up data to generate a useful feature.

# %% [markdown]
# ### 5.2 - Historical Record vs All Opponents

# %% [markdown]
# Defintions:
#  - **Historical Record vs All (HRVA):**
#      - **Variable Name**: hrva_rwma
#      - **Description**: Lagging indicator of past performance vs all opponents based on _results_ variable
#
#
#
#  - **Historical Record vs All "Plus" (HRVAP):**
#      - **Variable Name**: hrvap_rwma
#      - **Description**: Lagging indicator of past performance vs all opponents based on _results-plus_ variable

# %% [markdown]
# ### 5.2.1 - Generate Features

# %%
# Manipulate international results to get a dataframe that looks as follows:

# Date | home | team | tournament | result 

#df_home
df_home = pd.DataFrame(df, 
                       columns = ['date','home_team','tournament','result','result_plus'], 
                       copy = True)
df_home = df_home.rename(columns = {"home_team" : "team"})
df_home['home'] = 1

# %%
#df_away
df_away = pd.DataFrame(df, columns = ['date','away_team','tournament'], 
                       copy = True)
df_away = df_away.rename(columns = {"away_team" : "team"})
df_away['result'] = df['result'] * - 1
df_away['result_plus'] = df['result_plus'] * - 1
df_away['home'] = 0

# %%
#df_tall (combo of df_home and df_away)
df_tall = df_home.append(df_away, sort = True)

df_tall = df_tall.sort_values('date')

df_tall.set_index('date',inplace=True,drop=True)

#print(len(train_df))
#print(len(df_tall))
df_tall.head()
# Out:
#             home  result  result_plus      team tournament
# date
# 1872-11-30     1       0        -0.25  Scotland   Friendly
# 1872-11-30     0       0         0.25   England   Friendly
# 1873-03-08     1       1         0.75   England   Friendly
# 1873-03-08     0      -1        -0.75  Scotland   Friendly
# 1874-03-07     1       1         0.75  Scotland   Friendly

# %%
# Create fake rows to store forward int'l ranking

fake_df = pd.DataFrame(df_tall.team.unique(),columns=['team'])
fake_df['date'] = '2099-12-31'
fake_df.date = fake_df.date.values.astype("datetime64")
fake_df['home'] = '0'
fake_df['result'] = '0'
fake_df['result_plus'] = '0'
fake_df['tournament'] = 'Placeholder'
fake_df.set_index('date', inplace=True)
fake_df.head()
# Out:
#                         team home result result_plus   tournament
# date
# 2099-12-31          Scotland    0      0           0  Placeholder
# 2099-12-31           England    0      0           0  Placeholder
# 2099-12-31             Wales    0      0           0  Placeholder
# 2099-12-31  Northern Ireland    0      0           0  Placeholder
# 2099-12-31               USA    0      0           0  Placeholder

# %%
df_tall = pd.concat([df_tall,fake_df], sort=True)

# %%
df_tall.head()
# Out:
#            home result result_plus      team tournament
# date
# 1872-11-30    1      0       -0.25  Scotland   Friendly
# 1872-11-30    0      0        0.25   England   Friendly
# 1873-03-08    1      1        0.75   England   Friendly
# 1873-03-08    0     -1       -0.75  Scotland   Friendly
# 1874-03-07    1      1        0.75  Scotland   Friendly

# %%
overall_record_rwma_df = df_tall.groupby('team')['result'].apply(rwma,0,50)
overall_record_rwmap_df = df_tall.groupby('team')['result_plus'].apply(rwma,0,50)

overall_record_rmean_df = df_tall.groupby('team')['result'].apply(rmean,0)
overall_record_rmeanp_df = df_tall.groupby('team')['result_plus'].apply(rmean,0)

overall_record_df = overall_record_rwma_df.copy()

# %%
overall_record_df = overall_record_df.rename(columns = {'rwma':'hrva_rwma'})

overall_record_df['hrvap_rwma'] = overall_record_rwmap_df['rwma']

overall_record_df['hrva_rmean'] = overall_record_rmean_df['rmean']

overall_record_df['hrvap_rmean'] = overall_record_rmeanp_df['rmean']

# %%
overall_record_df.head()
# Out:
#                  date  hrva_rwma  hrvap_rwma  hrva_rmean  hrvap_rmean
# team
# Abkhazia 0 2014-06-01        NaN         NaN         NaN          NaN
#          1 2014-06-02   0.000000    0.000000    0.000000     0.000000
#          2 2014-06-04   0.510000    0.637500    0.500000     0.625000
#          3 2014-06-05   0.333156    0.416444    0.333333     0.416667
#          4 2014-06-07   0.244804    0.306005    0.250000     0.312500

# %%
overall_record_df.reset_index(inplace=True)

overall_record_df.drop(columns='level_1', inplace= True)

overall_record_df.hrva_rwma = overall_record_df.hrva_rwma.fillna(0)

overall_record_df.hrvap_rwma = overall_record_df.hrvap_rwma.fillna(0)

overall_record_df.hrva_rmean = overall_record_df.hrva_rmean.fillna(0)

overall_record_df.hrvap_rmean = overall_record_df.hrvap_rmean.fillna(0)

# below is needed to handle duplicates due to certain teams playing two matches on the same date
overall_record_df = overall_record_df.groupby(['team','date']).mean()
overall_record_df = overall_record_df.reset_index()

# %% [markdown]
# ### 5.2.2 - Examine Features

# %%
overall_record_df[overall_record_df['team'] == 'France'].head(10)
# Out:
#          team       date  hrva_rwma  hrvap_rwma  hrva_rmean  hrvap_rmean
# 23316  France 1904-05-01   0.000000    0.000000    0.000000     0.000000
# 23317  France 1905-02-12   0.000000    0.250000    0.000000     0.250000
# 23318  France 1905-05-07   0.510000    0.505000    0.500000     0.500000
# 23319  France 1906-04-22  -0.013598    0.069824    0.000000     0.083333
# 23320  France 1907-04-21  -0.275188   -0.280188   -0.250000    -0.250000
# 23321  France 1908-03-08   0.000652    0.050812    0.000000     0.050000
# 23322  France 1908-04-12   0.184301    0.271185    0.166667     0.250000
# 23323  France 1908-05-10  -0.005850    0.026945    0.000000     0.035714
# 23324  France 1909-05-09  -0.148197   -0.084302   -0.125000    -0.062500
# 23325  France 1910-04-03  -0.258675   -0.170643   -0.222222    -0.138889

# %%
overall_record_df[overall_record_df['team'] == 'France'].tail(10)
# Out:
#          team       date  hrva_rwma  hrvap_rwma  hrva_rmean  hrvap_rmean
# 24120  France 2017-10-07   0.452248    0.359116    0.330827     0.276316
# 24121  France 2017-10-10   0.473728    0.394053    0.348485     0.295455
# 24122  France 2017-11-10   0.494366    0.408011    0.348485     0.291667
# 24123  France 2017-11-14   0.514195    0.421423    0.348485     0.291667
# 24124  France 2018-03-23   0.494031    0.414700    0.348485     0.295455
# 24125  France 2018-03-27   0.435441    0.349418    0.351145     0.291985
# 24126  France 2018-05-28   0.457581    0.384735    0.351145     0.295802
# 24127  France 2018-06-01   0.478852    0.399059    0.351145     0.295802
# 24128  France 2018-06-09   0.499289    0.412821    0.353846     0.300000
# 24129  France 2099-12-31   0.425454    0.414643    0.371424     0.491640

# %%
temp_df1 = overall_record_df[(overall_record_df['team'] == 'France') & (overall_record_df['date'] < '2099-12-31')]
temp_df2 = overall_record_df[(overall_record_df['team'] == 'Spain')  & (overall_record_df['date'] < '2099-12-31')]
temp_df3 = df_vs_oppo[df_vs_oppo['sorted_matchup'] == 'France|Spain']

# %%
temp_df3.tail()
# Out:
#       sorted_matchup       date  hrvo_rwma  hrvop_rwma
# 23665   France|Spain 2012-10-16  -0.035608   -0.058321
# 23666   France|Spain 2013-03-26  -0.032639   -0.032620
# 23667   France|Spain 2014-09-04  -0.112761   -0.133450
# 23668   France|Spain 2017-03-28  -0.021137   -0.060707
# 23669   France|Spain 2099-12-31  -0.137920   -0.202595

# %%
fig, ax = plt.subplots(1,1, figsize = (20,10))

ax.plot(temp_df1['date'], temp_df1['hrva_rwma'], label = 'Argentina - hrva_rwma', color = 'blue', alpha = 1)
ax.plot(temp_df1['date'], temp_df1['hrvap_rwma'], label = 'Argentina - hrvap_rwma', color = 'blue', alpha = 0.60)

ax.plot(temp_df1['date'], temp_df1['hrva_rmean'], label = 'Argentina - hrva_rmean', color = 'blue', alpha = .40)
ax.plot(temp_df1['date'], temp_df1['hrvap_rmean'], label = 'Argentina - hrvap_rmean', color = 'blue', alpha = .20)


ax.plot(temp_df2['date'], temp_df2['hrva_rwma'], label = 'Brazil - hrva_rwma', color = 'red', alpha = 1)
ax.plot(temp_df2['date'], temp_df2['hrvap_rwma'], label = 'Brazil - hrvap_rwma', color = 'red', alpha = 0.60)

ax.plot(temp_df2['date'], temp_df2['hrva_rmean'], label = 'Brazil - hrva_rmean', color = 'red', alpha = .40)
ax.plot(temp_df2['date'], temp_df2['hrvap_rmean'], label = 'Brazil - hrvap_rmean', color = 'red', alpha = .20)

ax.set_xlabel('Moving Averages')
ax.set_ylabel('Rolling Means')
ax.set_title('Illustration of "Historical Record vs All" Features: Argentina vs. Brazil')

plt.legend()
plt.show()

# %% [markdown]
# ## 6  - Merge Features Back into Project Dataset

# %% [markdown]
# ### 6.1  - Merge Historical Record vs All Opponents into Project Dataset

# %%
project_df = pd.read_csv("data/team/M4_data_nikhil.csv")
project_df.date = project_df.date.values.astype("datetime64")

project_df = project_df.sort_values(['date','home_team','away_team'])
overall_record_df = overall_record_df.sort_values(['date','team'])

overall_record_df.to_csv('data/team/overall_record_df.csv')

# %%
#print(len(project_df))

merge_columms = ['date','team', # for joins
                 'hrva_rwma','hrvap_rwma','hrva_rmean','hrvap_rmean']

final_df = pd.merge_asof(project_df, overall_record_df[merge_columms], 
                  left_on=['date'],
                  right_on=['date'],                    
                  left_by = ['home_team'], 
                  right_by = ['team'], 
                  direction = 'forward',
                  allow_exact_matches = True)

final_df = final_df.drop(columns = 'team')

final_df = final_df.rename(columns={'hrva_rwma':'home_hrva_rwma', 
                                    'hrvap_rwma':'home_hrvap_rwma',
                                    'hrva_rmean':'home_hrva_rmean',
                                    'hrvap_rmean': 'home_hrvap_rmean'
                                    })

#print(len(final_df))

# %%
print(len(project_df))

final_df = pd.merge_asof(final_df, overall_record_df[merge_columms], 
                  left_on=['date'],
                  right_on=['date'],                    
                  left_by = ['away_team'], 
                  right_by = ['team'], 
                  direction = 'forward',
                  allow_exact_matches = True)


final_df = final_df.drop(columns = 'team')

#train_df.head()

final_df = final_df.rename(columns={'hrva_rwma':'away_hrva_rwma', 
                                    'hrvap_rwma':'away_hrvap_rwma',
                                    'hrva_rmean':'away_hrva_rmean',
                                    'hrvap_rmean': 'away_hrvap_rmean'
                                    })

print(len(final_df))
# Out:
# 1639
# 1639

# %%
#final_df.info()

# %%
#final_df.to_csv('data/team/final_df.csv')

# %%
final_df['diff_hrva_rwma']   = final_df['home_hrva_rwma']   - final_df['away_hrva_rwma']
final_df['diff_hrvap_rwma']  = final_df['home_hrvap_rwma']  - final_df['away_hrvap_rwma']
final_df['diff_hrva_rmean']  = final_df['home_hrva_rmean']  - final_df['away_hrva_rmean']
final_df['diff_hrvap_rmean'] = final_df['home_hrvap_rmean'] - final_df['away_hrvap_rmean']

# %% [markdown]
# ### 6.2  - Merge Historical Record vs Opponent into Project Dataset

# %%
df['hrvo_rwma'] = np.where(df['home_team'] < df['away_team'], 
                                df['hrvo_rwma'],
                                df['hrvo_rwma'] * -1 )

# %%
df['hrvop_rwma'] = np.where(df['home_team'] < df['away_team'], 
                                df['hrvop_rwma'],
                                df['hrvop_rwma'] * -1 )

# %%
df[df['date'] <= '2018-12-31'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39606 entries, 0 to 39605
# Data columns (total 18 columns):
# date                  39606 non-null datetime64[ns]
# away_score            39606 non-null int64
# away_team             39606 non-null object
# city                  39606 non-null object
# country               39606 non-null object
# home_score            39606 non-null int64
# home_team             39606 non-null object
# neutral               39606 non-null bool
# result                39606 non-null int64
# result_plus           39606 non-null float64
# sorted_matchup        39606 non-null object
# sorted_result         39606 non-null int64
# sorted_result_plus    39606 non-null float64
# tournament            39606 non-null object
# unsorted_matchup      39606 non-null object
# year                  39606 non-null int64
# hrvo_rwma             39606 non-null float64
# hrvop_rwma            39606 non-null float64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(5), object(7)
# memory usage: 5.5+ MB

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1639 entries, 0 to 1638
# Data columns (total 78 columns):
# date                                1639 non-null datetime64[ns]
# home_team                           1639 non-null object
# away_team                           1639 non-null object
# home_score                          1639 non-null int64
# away_score                          1639 non-null int64
# tournament                          1639 non-null object
# city                                1639 non-null object
# country                             1639 non-null object
# neutral                             1639 non-null int64
# home_rank                           1639 non-null int64
# home_rank_pts                       1639 non-null int64
# away_rank                           1639 non-null int64
# away_rank_pts                       1639 non-null int64
# rank_diff                           1639 non-null int64
# rank_pts_diff                       1639 non-null int64
# outcome                             1639 non-null object
# outcome_num                         1639 non-null int64
# home_game                           1639 non-null int64
# away_game                           1639 non-null int64
# home_OVR                            1639 non-null int64
# home_ATT                            1639 non-null int64
# home_MID                            1639 non-null int64
# home_DEF                            1639 non-null int64
# home_team_id                        1639 non-null int64
# home_team_uid                       1639 non-null object
# home_team_international_prestige    1639 non-null int64
# away_OVR                            1639 non-null int64
# away_ATT                            1639 non-null int64
# away_MID                            1639 non-null int64
# away_DEF                            1639 non-null int64
# away_team_id                        1639 non-null int64
# away_team_uid                       1639 non-null object
# away_team_international_prestige    1639 non-null int64
# ATT_diff                            1639 non-null int64
# DEF_diff                            1639 non-null int64
# MID_diff                            1639 non-null int64
# Friendly                            1639 non-null int64
# team_uid_x                          1639 non-null object
# home_ATT_age                        1639 non-null float64
# home_DEF_age                        1639 non-null float64
# home_MID_age                        1639 non-null float64
# home_ATT_ht                         1639 non-null float64
# home_DEF_ht                         1639 non-null float64
# home_MID_ht                         1639 non-null float64
# home_ATT_wt                         1639 non-null float64
# home_DEF_wt                         1639 non-null float64
# home_MID_wt                         1639 non-null float64
# team_uid_y                          1639 non-null object
# away_ATT_age                        1639 non-null float64
# away_DEF_age                        1639 non-null float64
# away_MID_age                        1639 non-null float64
# away_ATT_ht                         1639 non-null float64
# away_DEF_ht                         1639 non-null float64
# away_MID_ht                         1639 non-null float64
# away_ATT_wt                         1639 non-null float64
# away_DEF_wt                         1639 non-null float64
# away_MID_wt                         1639 non-null float64
# ATT_age_diff                        1639 non-null float64
# DEF_age_diff                        1639 non-null float64
# MID_age_diff                        1639 non-null float64
# ATT_ht_diff                         1639 non-null float64
# DEF_ht_diff                         1639 non-null float64
# MID_ht_diff                         1639 non-null float64
# ATT_wt_diff                         1639 non-null float64
# DEF_wt_diff                         1639 non-null float64
# MID_wt_diff                         1639 non-null float64
# home_hrva_rwma                      1639 non-null float64
# home_hrvap_rwma                     1639 non-null float64
# home_hrva_rmean                     1639 non-null float64
# home_hrvap_rmean                    1639 non-null float64
# away_hrva_rwma                      1639 non-null float64
# away_hrvap_rwma                     1639 non-null float64
# away_hrva_rmean                     1639 non-null float64
# away_hrvap_rmean                    1639 non-null float64
# diff_hrva_rwma                      1639 non-null float64
# diff_hrvap_rwma                     1639 non-null float64
# diff_hrva_rmean                     1639 non-null float64
# diff_hrvap_rmean                    1639 non-null float64
# dtypes: datetime64[ns](1), float64(39), int64(28), object(10)
# memory usage: 1011.6+ KB

# %%
merge_columms = ['date','home_team','away_team', # for joins
                 'hrvo_rwma' , 'hrvop_rwma']

final_df = pd.merge_asof(final_df, df[merge_columms], 
                  left_on=['date'],
                  right_on=['date'],                    
                  left_by = ['home_team','away_team'], 
                  right_by = ['home_team','away_team'], 
                  direction = 'forward',
                  allow_exact_matches = True)

#if teams never faced each other before, substitute hrvo_rwma and hrvop_rwma with diff_hrva_rwma and diff_hrvap_rwma

# %%
final_df[(final_df['home_team'] == 'Uruguay') & (final_df['away_team'] == 'Portugal')]
# Out:
#            date home_team away_team  home_score  away_score      tournament  \
# 1624 2018-06-30   Uruguay  Portugal           2           1  FIFA World Cup
#
#        city country  neutral  home_rank     ...      away_hrva_rwma  \
# 1624  Sochi  Russia        1         14     ...            0.419626
#
#       away_hrvap_rwma  away_hrva_rmean  away_hrvap_rmean  diff_hrva_rwma  \
# 1624         0.411844         0.423798          0.513079       -0.248041
#
#      diff_hrvap_rwma  diff_hrva_rmean  diff_hrvap_rmean  hrvo_rwma  hrvop_rwma
# 1624       -0.161751        -0.278734         -0.212611        NaN         NaN
#
# [1 rows x 80 columns]

# %%
final_df['hrvo_rwma'] = final_df['hrvo_rwma'].fillna(final_df['diff_hrva_rwma'])
final_df['hrvop_rwma'] = final_df['hrvop_rwma'].fillna(final_df['diff_hrvap_rwma'])

# %%
final_df[(final_df['home_team'] == 'Uruguay') & (final_df['away_team'] == 'Portugal')]
# Out:
#            date home_team away_team  home_score  away_score      tournament  \
# 1624 2018-06-30   Uruguay  Portugal           2           1  FIFA World Cup
#
#        city country  neutral  home_rank     ...      away_hrva_rwma  \
# 1624  Sochi  Russia        1         14     ...            0.419626
#
#       away_hrvap_rwma  away_hrva_rmean  away_hrvap_rmean  diff_hrva_rwma  \
# 1624         0.411844         0.423798          0.513079       -0.248041
#
#      diff_hrvap_rwma  diff_hrva_rmean  diff_hrvap_rmean  hrvo_rwma  hrvop_rwma
# 1624       -0.161751        -0.278734         -0.212611  -0.248041   -0.161751
#
# [1 rows x 80 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1639 entries, 0 to 1638
# Data columns (total 80 columns):
# date                                1639 non-null datetime64[ns]
# home_team                           1639 non-null object
# away_team                           1639 non-null object
# home_score                          1639 non-null int64
# away_score                          1639 non-null int64
# tournament                          1639 non-null object
# city                                1639 non-null object
# country                             1639 non-null object
# neutral                             1639 non-null int64
# home_rank                           1639 non-null int64
# home_rank_pts                       1639 non-null int64
# away_rank                           1639 non-null int64
# away_rank_pts                       1639 non-null int64
# rank_diff                           1639 non-null int64
# rank_pts_diff                       1639 non-null int64
# outcome                             1639 non-null object
# outcome_num                         1639 non-null int64
# home_game                           1639 non-null int64
# away_game                           1639 non-null int64
# home_OVR                            1639 non-null int64
# home_ATT                            1639 non-null int64
# home_MID                            1639 non-null int64
# home_DEF                            1639 non-null int64
# home_team_id                        1639 non-null int64
# home_team_uid                       1639 non-null object
# home_team_international_prestige    1639 non-null int64
# away_OVR                            1639 non-null int64
# away_ATT                            1639 non-null int64
# away_MID                            1639 non-null int64
# away_DEF                            1639 non-null int64
# away_team_id                        1639 non-null int64
# away_team_uid                       1639 non-null object
# away_team_international_prestige    1639 non-null int64
# ATT_diff                            1639 non-null int64
# DEF_diff                            1639 non-null int64
# MID_diff                            1639 non-null int64
# Friendly                            1639 non-null int64
# team_uid_x                          1639 non-null object
# home_ATT_age                        1639 non-null float64
# home_DEF_age                        1639 non-null float64
# home_MID_age                        1639 non-null float64
# home_ATT_ht                         1639 non-null float64
# home_DEF_ht                         1639 non-null float64
# home_MID_ht                         1639 non-null float64
# home_ATT_wt                         1639 non-null float64
# home_DEF_wt                         1639 non-null float64
# home_MID_wt                         1639 non-null float64
# team_uid_y                          1639 non-null object
# away_ATT_age                        1639 non-null float64
# away_DEF_age                        1639 non-null float64
# away_MID_age                        1639 non-null float64
# away_ATT_ht                         1639 non-null float64
# away_DEF_ht                         1639 non-null float64
# away_MID_ht                         1639 non-null float64
# away_ATT_wt                         1639 non-null float64
# away_DEF_wt                         1639 non-null float64
# away_MID_wt                         1639 non-null float64
# ATT_age_diff                        1639 non-null float64
# DEF_age_diff                        1639 non-null float64
# MID_age_diff                        1639 non-null float64
# ATT_ht_diff                         1639 non-null float64
# DEF_ht_diff                         1639 non-null float64
# MID_ht_diff                         1639 non-null float64
# ATT_wt_diff                         1639 non-null float64
# DEF_wt_diff                         1639 non-null float64
# MID_wt_diff                         1639 non-null float64
# home_hrva_rwma                      1639 non-null float64
# home_hrvap_rwma                     1639 non-null float64
# home_hrva_rmean                     1639 non-null float64
# home_hrvap_rmean                    1639 non-null float64
# away_hrva_rwma                      1639 non-null float64
# away_hrvap_rwma                     1639 non-null float64
# away_hrva_rmean                     1639 non-null float64
# away_hrvap_rmean                    1639 non-null float64
# diff_hrva_rwma                      1639 non-null float64
# diff_hrvap_rwma                     1639 non-null float64
# diff_hrva_rmean                     1639 non-null float64
# diff_hrvap_rmean                    1639 non-null float64
# hrvo_rwma                           1639 non-null float64
# hrvop_rwma                          1639 non-null float64
# dtypes: datetime64[ns](1), float64(41), int64(28), object(10)
# memory usage: 1.1+ MB

# %%
final_df.to_csv('data/team/final_df.csv')

# %%
# Look at France vs Italy
temp_pair_plot_df = final_df[(final_df['home_team'] == 'Argentina') & (final_df['away_team'] == 'Brazil')]

temp_pair_plot_df.head()
# Out:
#            date  home_team away_team  home_score  away_score  \
# 139  2010-11-17  Argentina    Brazil           1           0
# 322  2011-09-14  Argentina    Brazil           0           0
# 574  2012-11-21  Argentina    Brazil           2           1
# 920  2014-10-11  Argentina    Brazil           0           2
# 1095 2015-11-13  Argentina    Brazil           1           1
#
#                         tournament          city    country  neutral  \
# 139                       Friendly          Doha      Qatar        1
# 322                       Friendly       Córdoba  Argentina        0
# 574                       Friendly  Buenos Aires  Argentina        0
# 920                       Friendly       Beijing      China        1
# 1095  FIFA World Cup qualification  Buenos Aires  Argentina        0
#
#       home_rank     ...      away_hrva_rwma  away_hrvap_rwma  away_hrva_rmean  \
# 139           5     ...            0.682004         0.733183         0.483444
# 322           9     ...            0.481206         0.515303         0.513889
# 574           3     ...            0.572194         0.594870         0.510345
# 920           2     ...            0.501157         0.420045         0.540541
# 1095          3     ...            0.551902         0.511430         0.575540
#
#       away_hrvap_rmean  diff_hrva_rwma diff_hrvap_rwma  diff_hrva_rmean  \
# 139           0.529801       -0.208879       -0.250251        -0.039895
# 322           0.559028       -0.052753       -0.115849        -0.104798
# 574           0.562069       -0.155835       -0.166457        -0.093079
# 920           0.550676        0.011624        0.116031        -0.118318
# 1095          0.582734       -0.190923       -0.121209        -0.160155
#
#       diff_hrvap_rmean  hrvo_rwma  hrvop_rwma
# 139          -0.041898  -0.339887   -0.349503
# 322          -0.117740  -0.236758   -0.245635
# 574          -0.114227  -0.243356   -0.229300
# 920          -0.108083  -0.147676   -0.153940
# 1095         -0.148118  -0.213263   -0.219045
#
# [5 rows x 80 columns]

# %%
final_df.to_csv('data/team/final_dataset.csv')

# %%
sns.pairplot(final_df, 
             vars = ['diff_hrva_rwma' , 'diff_hrvap_rwma' , 'diff_hrva_rmean' , 'diff_hrvap_rmean'] , 
             hue="outcome_num")

# %% [markdown]
# # Remove later - start

# %%
x_train = df[['hrvo_rwma']]
y_train = df['result']

# %%
x_test = df[['hrvo_rwma']]
y_test = df['result']

# %%
simple_logistic_model = LogisticRegressionCV(multi_class = 'ovr', cv=5, penalty='l2')
simple_logistic_model.fit(x_train, y_train)

lda = LinearDiscriminantAnalysis()
qda = QuadraticDiscriminantAnalysis()

lda.fit(x_train, y_train)
qda.fit(x_train, y_train)

print('Logistic Regression Train Score: ',simple_logistic_model.score(x_train, y_train))
print('Logistic Regression CV Train Score: ',cross_val_score(simple_logistic_model, x_train, y_train, cv=5).mean())
print('LDA Train Score: ',lda.score(x_train, y_train))
print('LDA CV Train Score: ',cross_val_score(lda, x_train, y_train, cv=5).mean())
print('QDA Train Score: ',qda.score(x_train, y_train))
print('QDA CV Train Score: ',cross_val_score(qda, x_train, y_train, cv=5).mean())
# Out:
# Logistic Regression Train Score:  0.563208752595
# Logistic Regression CV Train Score:  0.559959106356
# LDA Train Score:  0.562789490497
# LDA CV Train Score:  0.562235408374
# QDA Train Score:  0.562789490497
# QDA CV Train Score:  0.562315276592

# %%
# choosing lda and qda as they both produced very similar scores on CV data
print('Logistic Regression Test Score: ',simple_logistic_model.score(x_test, y_test))
print('LDA Test Score: ',lda.score(x_test, y_test))
print('QDA Test Score: ',qda.score(x_test, y_test))
# Out:
# Logistic Regression Test Score:  0.563208752595
# LDA Test Score:  0.562789490497
# QDA Test Score:  0.562789490497

# %%
# confusion matrix for the logistic regression model
pd.crosstab(np.array(y_test), simple_logistic_model.predict(x_test), margins=True, rownames=['Actual'], colnames=['Predicted'])
# Out:
# Predicted     -1      1    All
# Actual
# -1          7160   7245  14405
# 0           3187   8237  11424
# 1           3209  21050  24259
# All        13556  36532  50088

# %%
# confusion matrix for the lda model
pd.crosstab(np.array(y_test), lda.predict(x_test), margins=True, rownames=['Actual'], colnames=['Predicted'])
# Out:
# Predicted     -1      1    All
# Actual
# -1          7272   7133  14405
# 0           3323   8101  11424
# 1           3342  20917  24259
# All        13937  36151  50088

# %%
# confusion matrix for the qda model
pd.crosstab(np.array(y_test), qda.predict(x_test), margins=True, rownames=['Actual'], colnames=['Predicted'])
# Out:
# Predicted     -1      1    All
# Actual
# -1          7276   7129  14405
# 0           3326   8098  11424
# 1           3346  20913  24259
# All        13948  36140  50088

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1639 entries, 0 to 1638
# Data columns (total 80 columns):
# date                                1639 non-null datetime64[ns]
# home_team                           1639 non-null object
# away_team                           1639 non-null object
# home_score                          1639 non-null int64
# away_score                          1639 non-null int64
# tournament                          1639 non-null object
# city                                1639 non-null object
# country                             1639 non-null object
# neutral                             1639 non-null int64
# home_rank                           1639 non-null int64
# home_rank_pts                       1639 non-null int64
# away_rank                           1639 non-null int64
# away_rank_pts                       1639 non-null int64
# rank_diff                           1639 non-null int64
# rank_pts_diff                       1639 non-null int64
# outcome                             1639 non-null object
# outcome_num                         1639 non-null int64
# home_game                           1639 non-null int64
# away_game                           1639 non-null int64
# home_OVR                            1639 non-null int64
# home_ATT                            1639 non-null int64
# home_MID                            1639 non-null int64
# home_DEF                            1639 non-null int64
# home_team_id                        1639 non-null int64
# home_team_uid                       1639 non-null object
# home_team_international_prestige    1639 non-null int64
# away_OVR                            1639 non-null int64
# away_ATT                            1639 non-null int64
# away_MID                            1639 non-null int64
# away_DEF                            1639 non-null int64
# away_team_id                        1639 non-null int64
# away_team_uid                       1639 non-null object
# away_team_international_prestige    1639 non-null int64
# ATT_diff                            1639 non-null int64
# DEF_diff                            1639 non-null int64
# MID_diff                            1639 non-null int64
# Friendly                            1639 non-null int64
# team_uid_x                          1639 non-null object
# home_ATT_age                        1639 non-null float64
# home_DEF_age                        1639 non-null float64
# home_MID_age                        1639 non-null float64
# home_ATT_ht                         1639 non-null float64
# home_DEF_ht                         1639 non-null float64
# home_MID_ht                         1639 non-null float64
# home_ATT_wt                         1639 non-null float64
# home_DEF_wt                         1639 non-null float64
# home_MID_wt                         1639 non-null float64
# team_uid_y                          1639 non-null object
# away_ATT_age                        1639 non-null float64
# away_DEF_age                        1639 non-null float64
# away_MID_age                        1639 non-null float64
# away_ATT_ht                         1639 non-null float64
# away_DEF_ht                         1639 non-null float64
# away_MID_ht                         1639 non-null float64
# away_ATT_wt                         1639 non-null float64
# away_DEF_wt                         1639 non-null float64
# away_MID_wt                         1639 non-null float64
# ATT_age_diff                        1639 non-null float64
# DEF_age_diff                        1639 non-null float64
# MID_age_diff                        1639 non-null float64
# ATT_ht_diff                         1639 non-null float64
# DEF_ht_diff                         1639 non-null float64
# MID_ht_diff                         1639 non-null float64
# ATT_wt_diff                         1639 non-null float64
# DEF_wt_diff                         1639 non-null float64
# MID_wt_diff                         1639 non-null float64
# home_hrva_rwma                      1639 non-null float64
# home_hrvap_rwma                     1639 non-null float64
# home_hrva_rmean                     1639 non-null float64
# home_hrvap_rmean                    1639 non-null float64
# away_hrva_rwma                      1639 non-null float64
# away_hrvap_rwma                     1639 non-null float64
# away_hrva_rmean                     1639 non-null float64
# away_hrvap_rmean                    1639 non-null float64
# diff_hrva_rwma                      1639 non-null float64
# diff_hrvap_rwma                     1639 non-null float64
# diff_hrva_rmean                     1639 non-null float64
# diff_hrvap_rmean                    1639 non-null float64
# hrvo_rwma                           1620 non-null float64
# hrvop_rwma                          1620 non-null float64
# dtypes: datetime64[ns](1), float64(41), int64(28), object(10)
# memory usage: 1.1+ MB

# %%
project_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1639 entries, 0 to 646
# Data columns (total 66 columns):
# date                                1639 non-null datetime64[ns]
# home_team                           1639 non-null object
# away_team                           1639 non-null object
# home_score                          1639 non-null int64
# away_score                          1639 non-null int64
# tournament                          1639 non-null object
# city                                1639 non-null object
# country                             1639 non-null object
# neutral                             1639 non-null int64
# home_rank                           1639 non-null int64
# home_rank_pts                       1639 non-null int64
# away_rank                           1639 non-null int64
# away_rank_pts                       1639 non-null int64
# rank_diff                           1639 non-null int64
# rank_pts_diff                       1639 non-null int64
# outcome                             1639 non-null object
# outcome_num                         1639 non-null int64
# home_game                           1639 non-null int64
# away_game                           1639 non-null int64
# home_OVR                            1639 non-null int64
# home_ATT                            1639 non-null int64
# home_MID                            1639 non-null int64
# home_DEF                            1639 non-null int64
# home_team_id                        1639 non-null int64
# home_team_uid                       1639 non-null object
# home_team_international_prestige    1639 non-null int64
# away_OVR                            1639 non-null int64
# away_ATT                            1639 non-null int64
# away_MID                            1639 non-null int64
# away_DEF                            1639 non-null int64
# away_team_id                        1639 non-null int64
# away_team_uid                       1639 non-null object
# away_team_international_prestige    1639 non-null int64
# ATT_diff                            1639 non-null int64
# DEF_diff                            1639 non-null int64
# MID_diff                            1639 non-null int64
# Friendly                            1639 non-null int64
# team_uid_x                          1639 non-null object
# home_ATT_age                        1639 non-null float64
# home_DEF_age                        1639 non-null float64
# home_MID_age                        1639 non-null float64
# home_ATT_ht                         1639 non-null float64
# home_DEF_ht                         1639 non-null float64
# home_MID_ht                         1639 non-null float64
# home_ATT_wt                         1639 non-null float64
# home_DEF_wt                         1639 non-null float64
# home_MID_wt                         1639 non-null float64
# team_uid_y                          1639 non-null object
# away_ATT_age                        1639 non-null float64
# away_DEF_age                        1639 non-null float64
# away_MID_age                        1639 non-null float64
# away_ATT_ht                         1639 non-null float64
# away_DEF_ht                         1639 non-null float64
# away_MID_ht                         1639 non-null float64
# away_ATT_wt                         1639 non-null float64
# away_DEF_wt                         1639 non-null float64
# away_MID_wt                         1639 non-null float64
# ATT_age_diff                        1639 non-null float64
# DEF_age_diff                        1639 non-null float64
# MID_age_diff                        1639 non-null float64
# ATT_ht_diff                         1639 non-null float64
# DEF_ht_diff                         1639 non-null float64
# MID_ht_diff                         1639 non-null float64
# ATT_wt_diff                         1639 non-null float64
# DEF_wt_diff                         1639 non-null float64
# MID_wt_diff                         1639 non-null float64
# dtypes: datetime64[ns](1), float64(27), int64(28), object(10)
# memory usage: 857.9+ KB
